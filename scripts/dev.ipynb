# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Start

# %%
import random

# %% [markdown]
# # Game Level

# %%
from werewolf.constants import WinCondition, RoleType
from werewolf.roles import Werewolf, Villager, Seer, Witch, Hunter, Idiot
from werewolf.player.strategies import (
    WerewolfHeuristicStrategy, VillagerRandomStrategy, SeerRandomStrategy, 
    WitchRandomStrategy, HunterRandomStrategy, IdiotRandomStrategy
)
from werewolf.simulator import GameConfig, Simulator

from werewolf.game.game import Game
from werewolf.constants import GamePhase, GameResult, Faction, WinCondition, RoleType

# %%
roles_setup = [
    Werewolf(), Werewolf(), Werewolf(), Werewolf(),
    Villager(), Villager(), Villager(), Villager(),
    Seer(), Witch(), Hunter(), Idiot()
]
strategy_mapping = {
    RoleType.WEREWOLF: WerewolfHeuristicStrategy,
    RoleType.VILLAGER: VillagerRandomStrategy,
    RoleType.SEER: SeerRandomStrategy,
    RoleType.WITCH: WitchRandomStrategy,
    RoleType.HUNTER: HunterRandomStrategy,
    RoleType.IDIOT: IdiotRandomStrategy
}
config = GameConfig(
    roles_setup=roles_setup,
        strategy_mapping=strategy_mapping,
    win_condition=WinCondition.KILL_SIDE  # 屠边局
)

# %%
players = config.create_players()
roles = [p.role for p in players]
for i, p in enumerate(players):
    p.role = roles[i]
game = Game(players, config.win_condition)

# %% [markdown]
# ## Start

# %% [markdown]
# ### First Night

# %%
game.winner

# %%
alive_players = game.get_alive_players()
alive_players
# Out:
# [<Player 1: 狼人 (Alive)>,
#  <Player 2: 狼人 (Alive)>,
#  <Player 3: 狼人 (Alive)>,
#  <Player 4: 狼人 (Alive)>,
#  <Player 5: 平民 (Alive)>,
#  <Player 6: 平民 (Alive)>,
#  <Player 7: 平民 (Alive)>,
#  <Player 8: 平民 (Alive)>,
#  <Player 9: 预言家 (Alive)>,
#  <Player 10: 女巫 (Alive)>,
#  <Player 11: 猎人 (Alive)>,
#  <Player 12: 白痴 (Alive)>]

# %% [markdown]
# #### Wolf

# %%
wolves = [p for p in alive_players if p.role.faction == Faction.WEREWOLF]
wolves
# Out:
# [<Player 1: 狼人 (Alive)>,
#  <Player 2: 狼人 (Alive)>,
#  <Player 3: 狼人 (Alive)>,
#  <Player 4: 狼人 (Alive)>]

# %%
wolf = wolves[0]
wolf
# Out:
# <Player 1: 狼人 (Alive)>

# %%
wolf.strategy.act_night(wolf,game)
# Out:
# 6

# %%
wolf_targets = []
for wolf in wolves:
    target = wolf.act_night(game)
    if target:
        wolf_targets.append(target)

wolf_kill = None
if wolf_targets:
    wolf_kill = max(set(wolf_targets), key=wolf_targets.count)
[wolf_kill,wolf_targets]
# Out:
# [9, [12, 5, 9, 7]]

# %% [markdown]
# #### Seer

# %%
gods = [p for p in alive_players if p.role.faction == Faction.GOD]
gods.sort(key=lambda x: x.role.priority, reverse=True)

witch_save = False
witch_poison = None
gods
# Out:
# [<Player 9: 预言家 (Alive)>,
#  <Player 10: 女巫 (Alive)>,
#  <Player 11: 猎人 (Alive)>,
#  <Player 12: 白痴 (Alive)>]

# %%
god = gods[0]

# %%
result = god.role.perform_night_action(game, god)

# %%
alive_players = [
            p.player_id for p in game.get_alive_players() 
        ]
random.choice(alive_players)
# Out:
# 4

# %%
game.players[1].role.faction== Faction.WEREWOLF
# Out:
# True

# %% [markdown]
# ## run_night

# %%
game = WerewolfGame()
deaths = {}
# Out:
# 2026-02-17 12:21:23,162 - WerewolfGame - INFO - Game Initialized with roles:
# 2026-02-17 12:21:23,163 - WerewolfGame - INFO - Player 1 (狼人) - Alive
# 2026-02-17 12:21:23,163 - WerewolfGame - INFO - Player 2 (狼人) - Alive
# 2026-02-17 12:21:23,163 - WerewolfGame - INFO - Player 3 (狼人) - Alive
# 2026-02-17 12:21:23,163 - WerewolfGame - INFO - Player 4 (狼人) - Alive
# 2026-02-17 12:21:23,163 - WerewolfGame - INFO - Player 5 (平民) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 6 (平民) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 7 (平民) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 8 (平民) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 9 (预言家) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 10 (女巫) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 11 (猎人) - Alive
# 2026-02-17 12:21:23,164 - WerewolfGame - INFO - Player 12 (白痴) - Alive

# %% [markdown]
# ### Werewolf

# %%
wolves = game.get_players_by_role(RoleType.WEREWOLF)
alive_wolves = [p for p in wolves if p.is_alive]
wolf = alive_wolves[0]
print(wolf)
# Out:
# Player 1 (狼人) - Alive

# %%
votes = {}
alive_players = game.get_alive_players()
for wolf in alive_wolves:
    # Delegate to Role
    target = wolf.role.choose_kill_target(alive_players, wolf.knowledge_prob)
    if target:
        votes[target] = votes.get(target, 0) + 1
votes
# Out:
# {<player.Player at 0x10ac34860>: 4}

# %%
max_votes = max(votes.values())
top_targets = [t for t, count in votes.items() if count == max_votes]
wolf_kill = random.choice(top_targets)
deaths[wolf_kill] = "Wolf"
f"Wolves decided to kill {target} (Votes: {max_votes}/{len(alive_wolves)})"
# Out:
# 'Wolves decided to kill Player 5 (平民) - Alive  (Votes: 4/4)'

# %% [markdown]
# ### Seer

# %%
seer_list = game.get_players_by_role(RoleType.SEER)
seer = seer_list[0] if seer_list else None
check_target = seer.role.choose_check_target(game.get_alive_players(), seer.knowledge_prob)
print(check_target)
# Out:
# Player 1 (狼人) - Alive

# %%
seer.role.checked_players.append(check_target.id)
is_wolf = check_target.role.role_type == RoleType.WEREWOLF
fate = RoleType.WEREWOLF if is_wolf else RoleType.VILLAGER
seer.mark_role_certain(check_target.id, fate)
seer.knowledge_prob[check_target.id]
# Out:
# {<RoleType.WEREWOLF: '狼人'>: 1.0}

# %% [markdown]
# ### Witch

# %%
witch_list = game.get_players_by_role(RoleType.WITCH)
witch = witch_list[0] if witch_list else None

# %%
witch.role.choose_save_decision(wolf_kill, witch.knowledge_prob)
# Out:
# True

# %%
witch.role.use_antidote()
del deaths[wolf_kill]
wolf_kill.saved = True

# %%
poison_target = witch.role.choose_poison_target([p for p in game.get_alive_players() if p != witch], witch.knowledge_prob)
poison_target.id
# Out:
# 1

# %% [markdown]
# ## run_day

# %%
game.day_count += 1

# %% [markdown]
# ### run_sheriff_election

# %%
game.run_sheriff_election()
# Out:
# 2026-02-17 12:21:26,182 - WerewolfGame - INFO - Running Sheriff Election...
# 2026-02-17 12:21:26,182 - WerewolfGame - INFO - Player 9 (预言家) runs for Sheriff.
# 2026-02-17 12:21:26,182 - WerewolfGame - INFO - Player 10 (女巫) runs for Sheriff.
# 2026-02-17 12:21:26,183 - WerewolfGame - INFO - Candidates share information:
# 2026-02-17 12:21:26,183 - WerewolfGame - INFO - [Discussion] Seer 9 says: Player 1 is 狼人
# 2026-02-17 12:21:26,183 - WerewolfGame - INFO - [Discussion] Witch 10 says: I saved Player 5 last night! (Silver Water)
# 2026-02-17 12:21:26,183 - WerewolfGame - INFO - Sheriff is Player 9 (预言家)

# %%
game.players[6].knowledge_prob[1]
# Out:
# {<RoleType.WEREWOLF: '狼人'>: 1.0}

# %%
game.players[6].knowledge_prob[5]
# Out:
# {<RoleType.VILLAGER: '平民'>: 0.42857142857142855,
#  <RoleType.SEER: '预言家'>: 0.14285714285714288,
#  <RoleType.WITCH: '女巫'>: 0.14285714285714288,
#  <RoleType.HUNTER: '猎人'>: 0.14285714285714288,
#  <RoleType.IDIOT: '白痴'>: 0.14285714285714288}

# %% [markdown]
# ### handle death

# %%
night_deaths = deaths
night_deaths
# Out:
# {}

# %% [markdown]
# ### share_information

# %%
for p in game.get_alive_players():
    p.role.share_information(p, game.players)
# Out:
# 2026-02-17 12:14:06,844 - WerewolfGame - INFO - [Discussion] Seer 9 says: Player 1 is 狼人
# 2026-02-17 12:14:06,844 - WerewolfGame - INFO - [Discussion] Witch 10 says: I saved Player 5 last night! (Silver Water)

# %%
game.players[6].knowledge_prob[5]
# Out:
# {<RoleType.VILLAGER: '平民'>: 0.42857142857142855,
#  <RoleType.SEER: '预言家'>: 0.14285714285714288,
#  <RoleType.WITCH: '女巫'>: 0.14285714285714288,
#  <RoleType.HUNTER: '猎人'>: 0.14285714285714288,
#  <RoleType.IDIOT: '白痴'>: 0.14285714285714288}

# %% [markdown]
# ### run_sheriff_election

# %%
candidates = game.get_alive_players()

# %% [markdown]
# # Test

# %%
from main import run_simulation, main

# %%
result = run_simulation()
# Out:
# 2026-02-17 16:11:22,690 - WerewolfGame - INFO - Game Initialized with roles:
# 2026-02-17 16:11:22,691 - WerewolfGame - INFO - Player 1 (狼人) - Alive
# 2026-02-17 16:11:22,691 - WerewolfGame - INFO - Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,691 - WerewolfGame - INFO - Player 3 (平民) - Alive
# 2026-02-17 16:11:22,691 - WerewolfGame - INFO - Player 4 (平民) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 5 (猎人) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 6 (狼人) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 7 (平民) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 8 (狼人) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 9 (平民) - Alive
# 2026-02-17 16:11:22,692 - WerewolfGame - INFO - Player 10 (狼人) - Alive
# 2026-02-17 16:11:22,693 - WerewolfGame - INFO - Player 11 (白痴) - Alive
# 2026-02-17 16:11:22,693 - WerewolfGame - INFO - Player 12 (预言家) - Alive
# 2026-02-17 16:11:22,693 - WerewolfGame - INFO -
# --- Night 1 ---
# 2026-02-17 16:11:22,693 - WerewolfGame - DEBUG - Wolf 1 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,693 - WerewolfGame - DEBUG - Wolf 6 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,694 - WerewolfGame - DEBUG - Wolf 8 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,694 - WerewolfGame - DEBUG - Wolf 10 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,694 - WerewolfGame - INFO - Wolves decided to kill Player 2 (女巫) - Alive  (Votes: 4/4)
# 2026-02-17 16:11:22,694 - WerewolfGame - INFO - Seer 12 checked 1 (狼人). Valid: True
# 2026-02-17 16:11:22,694 - WerewolfGame - INFO - Witch used antidote on 2
# 2026-02-17 16:11:22,694 - WerewolfGame - INFO -
# --- Day 1 ---
# 2026-02-17 16:11:22,694 - WerewolfGame - INFO - Running Sheriff Election...
# 2026-02-17 16:11:22,695 - WerewolfGame - INFO - Player 2 (女巫) runs for Sheriff.
# 2026-02-17 16:11:22,695 - WerewolfGame - INFO - Player 12 (预言家) runs for Sheriff.
# 2026-02-17 16:11:22,695 - WerewolfGame - INFO - Candidates share information:
# 2026-02-17 16:11:22,695 - WerewolfGame - INFO - [Discussion] Witch 2 says: I saved Player 2 last night! (Silver Water)
# 2026-02-17 16:11:22,696 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 1 is 狼人
# 2026-02-17 16:11:22,696 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 2 is 女巫
# 2026-02-17 16:11:22,696 - WerewolfGame - INFO - Sheriff is Player 12 (预言家)
# 2026-02-17 16:11:22,696 - WerewolfGame - INFO - 平安夜 (No one died last night).
# 2026-02-17 16:11:22,696 - WerewolfGame - INFO - [Discussion] Witch 2 says: I saved Player 2 last night! (Silver Water)
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 1 is 狼人
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 2 is 女巫
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - [Discussion] Seer 12 announces Badge Flow: Tonight will check Player 3. If Good -> Transfer to them; If Wolf -> Transfer to previously known good.
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - Player 1 votes -> 2
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - Player 2 votes -> 1
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - Player 3 votes -> 1
# 2026-02-17 16:11:22,697 - WerewolfGame - INFO - Player 4 votes -> 1
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 5 votes -> 1
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 6 votes -> 2
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 7 votes -> 1
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 8 votes -> 2
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 9 votes -> 1
# 2026-02-17 16:11:22,698 - WerewolfGame - INFO - Player 10 votes -> 2
# 2026-02-17 16:11:22,699 - WerewolfGame - INFO - Player 11 votes -> 1
# 2026-02-17 16:11:22,699 - WerewolfGame - INFO - Player 12 votes -> 1
# 2026-02-17 16:11:22,699 - WerewolfGame - INFO - Vote Counts: Player 2: 4.0, Player 1: 8.5
# 2026-02-17 16:11:22,699 - WerewolfGame - INFO - Voting Result: Player 1 is executed!
# 2026-02-17 16:11:22,699 - WerewolfGame - INFO -
# --- Night 2 ---
# 2026-02-17 16:11:22,699 - WerewolfGame - DEBUG - Wolf 6 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,699 - WerewolfGame - DEBUG - Wolf 8 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,699 - WerewolfGame - DEBUG - Wolf 10 votes for Player 2 (女巫) - Alive
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - Wolves decided to kill Player 2 (女巫) - Alive  (Votes: 3/3)
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - Seer 12 checked 3 (平民). Valid: False
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - Witch uses poison on Player 4
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO -
# --- Day 2 ---
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - Player 2 died last night.
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - Player 4 died last night.
# 2026-02-17 16:11:22,700 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 1 is 狼人
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 2 is 女巫
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - [Discussion] Seer 12 says: Player 3 is 平民
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - [Discussion] Seer 12 announces Badge Flow: Tonight will check Player 5. If Good -> Transfer to them; If Wolf -> Transfer to previously known good.
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - Player 3 votes -> 6
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - Player 5 votes -> 6
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - Player 6 votes -> 12
# 2026-02-17 16:11:22,701 - WerewolfGame - INFO - Player 7 votes -> 6
# 2026-02-17 16:11:22,702 - WerewolfGame - INFO - Player 8 votes -> 12
# 2026-02-17 16:11:22,702 - WerewolfGame - INFO - Player 9 votes -> 6
# 2026-02-17 16:11:22,702 - WerewolfGame - INFO - Player 10 votes -> 12
# 2026-02-17 16:11:22,702 - WerewolfGame - INFO - Player 11 votes -> 6
# 2026-02-17 16:11:22,702 - WerewolfGame - INFO - Player 12 votes -> 6
# 2026-02-17 16:11:22,703 - WerewolfGame - INFO - Vote Counts: Player 6: 6.5, Player 12: 3.0
# 2026-02-17 16:11:22,703 - WerewolfGame - INFO - Voting Result: Player 6 is executed!
# 2026-02-17 16:11:22,703 - WerewolfGame - INFO -
# --- Night 3 ---
# 2026-02-17 16:11:22,703 - WerewolfGame - DEBUG - Wolf 8 votes for Player 12 (预言家) - Alive [Sheriff]
# 2026-02-17 16:11:22,703 - WerewolfGame - DEBUG - Wolf 10 votes for Player 12 (预言家) - Alive [Sheriff]
# 2026-02-17 16:11:22,703 - WerewolfGame - INFO - Wolves decided to kill Player 12 (预言家) - Alive [Sheriff] (Votes: 2/2)
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO - Seer 12 checked 5 (猎人). Valid: False
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO -
# --- Day 3 ---
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO - Player 12 died last night.
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO - Sheriff 12 died. Transferring badge...
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO - Seer Badge Flow: Player 5 is Good. Transferring badge and revealing their role to all.
# 2026-02-17 16:11:22,704 - WerewolfGame - INFO - New Sheriff is Player 5
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 3 votes -> 7
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 5 votes -> 7
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 7 votes -> 8
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 8 votes -> 3
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 9 votes -> 7
# 2026-02-17 16:11:22,705 - WerewolfGame - INFO - Player 10 votes -> 3
# 2026-02-17 16:11:22,706 - WerewolfGame - INFO - Player 11 votes -> 7
# 2026-02-17 16:11:22,706 - WerewolfGame - INFO - Vote Counts: Player 7: 4.5, Player 8: 1.0, Player 3: 2.0
# 2026-02-17 16:11:22,706 - WerewolfGame - INFO - Voting Result: Player 7 is executed!
# 2026-02-17 16:11:22,706 - WerewolfGame - INFO -
# --- Night 4 ---
# 2026-02-17 16:11:22,707 - WerewolfGame - DEBUG - Wolf 8 votes for Player 3 (平民) - Alive
# 2026-02-17 16:11:22,707 - WerewolfGame - DEBUG - Wolf 10 votes for Player 3 (平民) - Alive
# 2026-02-17 16:11:22,707 - WerewolfGame - INFO - Wolves decided to kill Player 3 (平民) - Alive  (Votes: 2/2)
# 2026-02-17 16:11:22,707 - WerewolfGame - INFO -
# --- Day 4 ---
# 2026-02-17 16:11:22,707 - WerewolfGame - INFO - Player 3 died last night.
# 2026-02-17 16:11:22,707 - WerewolfGame - INFO - Player 5 votes -> 8
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Player 8 votes -> 5
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Player 9 votes -> 8
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Player 10 votes -> 5
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Player 11 votes -> 8
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Vote Counts: Player 8: 3.5, Player 5: 2.0
# 2026-02-17 16:11:22,708 - WerewolfGame - INFO - Voting Result: Player 8 is executed!
# 2026-02-17 16:11:22,709 - WerewolfGame - INFO -
# --- Night 5 ---
# 2026-02-17 16:11:22,709 - WerewolfGame - DEBUG - Wolf 10 votes for Player 5 (猎人) - Alive [Sheriff]
# 2026-02-17 16:11:22,709 - WerewolfGame - INFO - Wolves decided to kill Player 5 (猎人) - Alive [Sheriff] (Votes: 1/1)
# 2026-02-17 16:11:22,709 - WerewolfGame - INFO -
# --- Day 5 ---
# 2026-02-17 16:11:22,709 - WerewolfGame - INFO - Player 5 died last night.
# 2026-02-17 16:11:22,710 - WerewolfGame - INFO - Sheriff 5 died. Transferring badge...
# 2026-02-17 16:11:22,710 - WerewolfGame - INFO - New Sheriff is Player 11
# 2026-02-17 16:11:22,710 - WerewolfGame - INFO - Hunter 5 triggers skill!
# 2026-02-17 16:11:22,710 - WerewolfGame - INFO - Hunter shoots Player 11
# 2026-02-17 16:11:22,710 - WerewolfGame - INFO - Sheriff 11 died. Transferring badge...
# 2026-02-17 16:11:22,711 - WerewolfGame - INFO - New Sheriff is Player 10
# 2026-02-17 16:11:22,711 - WerewolfGame - INFO - Game Over! Winner: Werewolves (All Gods Dead - Slaughter)
